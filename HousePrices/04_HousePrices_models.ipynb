# %%
# !set PYTHONIOENCODING=utf-8
# !jupyter notebook
# Out:
# ^C

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import config
import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostRegressor

# %%
df = pd.read_csv(config.CONFIG['paths']['train_with_folds'])
TARGET_COL = config.CONFIG['validation']['target_column']
N_SPLITS = config.CONFIG['validation']['n_splits']
print('Таргет', TARGET_COL, 'Фолды', N_SPLITS)
# Out:
# Таргет SalePrice Фолды 5

# %%
feature_cols = [c for c in df.columns 
                if c not in [TARGET_COL, 'fold'] 
                and pd.api.types.is_numeric_dtype(df[c])]

print('Число фич', len(feature_cols))
# Out:
# Число фич 288

# %% [markdown]
# # считаем RMSE

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
def run_cv_regression(model_cls, model_params, df, target_col=TARGET_COL, n_splits=N_SPLITS):
    oof = np.zeros(len(df))
    scores = []

    for fold in range(n_splits):
        train_mask = df['fold'] != fold
        val_mask = df['fold'] == fold
        X_train = df.loc[train_mask, feature_cols]
        y_train = df.loc[train_mask, target_col]
        X_val = df.loc[val_mask, feature_cols]
        y_val = df.loc[val_mask, target_col]
        model = model_cls(**model_params)
        model.fit(X_train, y_train)
        preds = model.predict(X_val)
        oof[val_mask] = preds
        sc = rmse(y_val, preds)
        scores.append(sc)
        print(f"fold {fold} : RMSE = {sc:.4f}")

    print(f"mean RMSE: {np.mean(scores):.4f} +- {np.std(scores):.4f}")
    return oof, scores

# %% [markdown]
# # Лин регрессия

# %%
results = []

# %%
_, s = run_cv_regression(LinearRegression, config.CONFIG['models']['linear_regression'], df)
results.append({'model': 'LinearRegression', 'mean_rmse': np.mean(s), 'std_rmse': np.std(s)})
# Out:
# fold 0 : RMSE = 0.1279
# fold 1 : RMSE = 0.1253
# fold 2 : RMSE = 0.2403
# fold 3 : RMSE = 0.1555
# fold 4 : RMSE = 0.1131
# mean RMSE: 0.1524 +- 0.0461

# %% [markdown]
# # Ridge, Lasso, ElasticNEt

# %%
_, s = run_cv_regression(Ridge, config.CONFIG['models']['ridge'], df)
results.append({'model': 'Ridge', 'mean_rmse': np.mean(s), 'std_rmse': np.std(s)})
# Out:
# fold 0 : RMSE = 0.1358
# fold 1 : RMSE = 0.1303
# fold 2 : RMSE = 0.2242
# fold 3 : RMSE = 0.1275
# fold 4 : RMSE = 0.1163
# mean RMSE: 0.1468 +- 0.0392

# %%
_, s = run_cv_regression(Lasso, config.CONFIG['models']['lasso'], df)
results.append({'model': 'Lasso', 'mean_rmse': np.mean(s), 'std_rmse': np.std(s)})
# Out:
# fold 0 : RMSE = 0.1276
# fold 1 : RMSE = 0.1219
# fold 2 : RMSE = 0.2256
# fold 3 : RMSE = 0.1246
# fold 4 : RMSE = 0.1066
# mean RMSE: 0.1412 +- 0.0428

# %%
_, s = run_cv_regression(ElasticNet, config.CONFIG['models']['elasticnet'], df)
results.append({'model': 'ElasticNet', 'mean_rmse': np.mean(s), 'std_rmse': np.std(s)})
# Out:
# fold 0 : RMSE = 0.1257
# fold 1 : RMSE = 0.1246
# fold 2 : RMSE = 0.2256
# fold 3 : RMSE = 0.1276
# fold 4 : RMSE = 0.1093
# mean RMSE: 0.1426 +- 0.0420

# %% [markdown]
# # knn

# %%
_, s = run_cv_regression(KNeighborsRegressor, config.CONFIG['models']['knn'], df)
results.append({'model': 'KNN', 'mean_rmse': np.mean(s), 'std_rmse': np.std(s)})
# Out:
# Exception in thread Thread-275 (_readerthread):
# Traceback (most recent call last):
#   File "c:\newTry2\condaR\envs\ml_final\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\newTry2\condaR\envs\ml_final\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\newTry2\condaR\envs\ml_final\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
#   File "c:\newTry2\condaR\envs\ml_final\lib\codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8d in position 4: invalid start byte
# fold 0 : RMSE = 0.3723
# fold 1 : RMSE = 0.3301
# fold 2 : RMSE = 0.3078
# fold 3 : RMSE = 0.3420
# fold 4 : RMSE = 0.2956
# mean RMSE: 0.3296 +- 0.0269

# %% [markdown]
# # Tree

# %%
_, s = run_cv_regression(DecisionTreeRegressor, config.CONFIG['models']['decision_tree'], df)
results.append({'model': 'DecisionTree', 'mean_rmse': np.mean(s), 'std_rmse': np.std(s)})
# Out:
# fold 0 : RMSE = 0.1915
# fold 1 : RMSE = 0.2105
# fold 2 : RMSE = 0.2136
# fold 3 : RMSE = 0.1932
# fold 4 : RMSE = 0.1984
# mean RMSE: 0.2014 +- 0.0090

# %% [markdown]
# # Random forest

# %%
_, s = run_cv_regression(RandomForestRegressor, config.CONFIG['models']['random_forest'], df)
results.append({'model': 'RandomForest', 'mean_rmse': np.mean(s), 'std_rmse': np.std(s)})
# Out:
# fold 0 : RMSE = 0.1474
# fold 1 : RMSE = 0.1275
# fold 2 : RMSE = 0.1773
# fold 3 : RMSE = 0.1503
# fold 4 : RMSE = 0.1245
# mean RMSE: 0.1454 +- 0.0190

# %% [markdown]
# # Бустинги

# %%
params = {**config.CONFIG['models']['xgboost'], 'random_state': config.CONFIG['seed']}
_, s = run_cv_regression(xgb.XGBRegressor, params, df)
results.append({'model': 'XGBoost', 'mean_rmse': np.mean(s), 'std_rmse': np.std(s)})
# Out:
# fold 0 : RMSE = 0.1292
# fold 1 : RMSE = 0.1136
# fold 2 : RMSE = 0.1558
# fold 3 : RMSE = 0.1248
# fold 4 : RMSE = 0.1046
# mean RMSE: 0.1256 +- 0.0174

# %%
_, s = run_cv_regression(lgb.LGBMRegressor, config.CONFIG['models']['lightgbm'], df)
results.append({'model': 'LightGBM', 'mean_rmse': np.mean(s), 'std_rmse': np.std(s)})
# Out:
# fold 0 : RMSE = 0.1410
# fold 1 : RMSE = 0.1205
# fold 2 : RMSE = 0.1662
# fold 3 : RMSE = 0.1314
# fold 4 : RMSE = 0.1137
# mean RMSE: 0.1345 +- 0.0184

# %%
_, s = run_cv_regression(CatBoostRegressor, config.CONFIG['models']['catboost'], df)
results.append({'model': 'CatBoost', 'mean_rmse': np.mean(s), 'std_rmse': np.std(s)})
# Out:
# 0:	learn: 0.3856104	total: 153ms	remaining: 12m 45s
# 200:	learn: 0.1197089	total: 716ms	remaining: 17.1s
# 400:	learn: 0.0918064	total: 1.24s	remaining: 14.2s
# 600:	learn: 0.0788432	total: 1.72s	remaining: 12.6s
# 800:	learn: 0.0687025	total: 2.23s	remaining: 11.7s
# 1000:	learn: 0.0601990	total: 2.74s	remaining: 10.9s
# 1200:	learn: 0.0537837	total: 3.24s	remaining: 10.2s
# 1400:	learn: 0.0477912	total: 3.76s	remaining: 9.65s
# 1600:	learn: 0.0427435	total: 4.26s	remaining: 9.05s
# 1800:	learn: 0.0385172	total: 4.78s	remaining: 8.49s
# 2000:	learn: 0.0348256	total: 5.27s	remaining: 7.9s
# 2200:	learn: 0.0315820	total: 5.78s	remaining: 7.35s
# 2400:	learn: 0.0286791	total: 6.29s	remaining: 6.81s
# 2600:	learn: 0.0261069	total: 6.79s	remaining: 6.26s
# 2800:	learn: 0.0237328	total: 7.31s	remaining: 5.74s
# 3000:	learn: 0.0215937	total: 7.82s	remaining: 5.21s
# 3200:	learn: 0.0196647	total: 8.38s	remaining: 4.71s
# 3400:	learn: 0.0179663	total: 8.94s	remaining: 4.2s
# 3600:	learn: 0.0164693	total: 9.46s	remaining: 3.67s
# 3800:	learn: 0.0151519	total: 9.96s	remaining: 3.14s
# 4000:	learn: 0.0139909	total: 10.5s	remaining: 2.62s
# 4200:	learn: 0.0129252	total: 11s	remaining: 2.09s
# 4400:	learn: 0.0119217	total: 11.5s	remaining: 1.56s
# 4600:	learn: 0.0109269	total: 12s	remaining: 1.04s
# 4800:	learn: 0.0100899	total: 12.5s	remaining: 519ms
# 4999:	learn: 0.0092959	total: 13s	remaining: 0us
# fold 0 : RMSE = 0.1274
# 0:	learn: 0.3960854	total: 2.75ms	remaining: 13.8s
# 200:	learn: 0.1206787	total: 512ms	remaining: 12.2s
# 400:	learn: 0.0924889	total: 1.03s	remaining: 11.8s
# 600:	learn: 0.0778341	total: 1.53s	remaining: 11.2s
# 800:	learn: 0.0682030	total: 2.03s	remaining: 10.6s
# 1000:	learn: 0.0602172	total: 2.55s	remaining: 10.2s
# 1200:	learn: 0.0530843	total: 3.06s	remaining: 9.68s
# 1400:	learn: 0.0472012	total: 3.58s	remaining: 9.19s
# 1600:	learn: 0.0422797	total: 4.08s	remaining: 8.65s
# 1800:	learn: 0.0382571	total: 4.6s	remaining: 8.17s
# 2000:	learn: 0.0345997	total: 5.11s	remaining: 7.65s
# 2200:	learn: 0.0315258	total: 5.61s	remaining: 7.14s
# 2400:	learn: 0.0283411	total: 6.15s	remaining: 6.65s
# 2600:	learn: 0.0258955	total: 6.64s	remaining: 6.13s
# 2800:	learn: 0.0235474	total: 7.17s	remaining: 5.63s
# 3000:	learn: 0.0215588	total: 7.69s	remaining: 5.12s
# 3200:	learn: 0.0197431	total: 8.2s	remaining: 4.61s
# 3400:	learn: 0.0180724	total: 8.7s	remaining: 4.09s
# 3600:	learn: 0.0166455	total: 9.21s	remaining: 3.58s
# 3800:	learn: 0.0152483	total: 9.73s	remaining: 3.07s
# 4000:	learn: 0.0140738	total: 10.2s	remaining: 2.56s
# 4200:	learn: 0.0129208	total: 10.8s	remaining: 2.04s
# 4400:	learn: 0.0119071	total: 11.3s	remaining: 1.53s
# 4600:	learn: 0.0110248	total: 11.8s	remaining: 1.02s
# 4800:	learn: 0.0101871	total: 12.3s	remaining: 509ms
# 4999:	learn: 0.0093805	total: 12.8s	remaining: 0us
# fold 1 : RMSE = 0.1093
# 0:	learn: 0.4001021	total: 2.46ms	remaining: 12.3s
# 200:	learn: 0.1164741	total: 497ms	remaining: 11.9s
# 400:	learn: 0.0908339	total: 990ms	remaining: 11.4s
# 600:	learn: 0.0787478	total: 1.5s	remaining: 11s
# 800:	learn: 0.0690128	total: 2s	remaining: 10.5s
# 1000:	learn: 0.0604371	total: 2.53s	remaining: 10.1s
# 1200:	learn: 0.0540486	total: 3.03s	remaining: 9.59s
# 1400:	learn: 0.0484215	total: 3.54s	remaining: 9.1s
# 1600:	learn: 0.0432864	total: 4.04s	remaining: 8.59s
# 1800:	learn: 0.0389494	total: 4.54s	remaining: 8.07s
# 2000:	learn: 0.0347080	total: 5.13s	remaining: 7.68s
# 2200:	learn: 0.0312913	total: 5.62s	remaining: 7.15s
# 2400:	learn: 0.0280787	total: 6.14s	remaining: 6.65s
# 2600:	learn: 0.0255345	total: 6.63s	remaining: 6.12s
# 2800:	learn: 0.0232311	total: 7.14s	remaining: 5.61s
# 3000:	learn: 0.0211879	total: 7.63s	remaining: 5.08s
# 3200:	learn: 0.0193957	total: 8.13s	remaining: 4.57s
# 3400:	learn: 0.0177944	total: 8.66s	remaining: 4.07s
# 3600:	learn: 0.0161831	total: 9.15s	remaining: 3.55s
# 3800:	learn: 0.0147967	total: 9.67s	remaining: 3.05s
# 4000:	learn: 0.0135695	total: 10.2s	remaining: 2.54s
# 4200:	learn: 0.0124729	total: 10.7s	remaining: 2.03s
# 4400:	learn: 0.0115788	total: 11.2s	remaining: 1.52s
# 4600:	learn: 0.0106088	total: 11.7s	remaining: 1.01s
# 4800:	learn: 0.0098473	total: 12.2s	remaining: 507ms
# 4999:	learn: 0.0090806	total: 12.7s	remaining: 0us
# fold 2 : RMSE = 0.1542
# 0:	learn: 0.3892687	total: 2.61ms	remaining: 13.1s
# 200:	learn: 0.1195738	total: 526ms	remaining: 12.6s
# 400:	learn: 0.0937595	total: 1.03s	remaining: 11.8s
# 600:	learn: 0.0801408	total: 1.57s	remaining: 11.5s
# 800:	learn: 0.0697715	total: 2.07s	remaining: 10.9s
# 1000:	learn: 0.0615414	total: 2.58s	remaining: 10.3s
# 1200:	learn: 0.0558152	total: 3.09s	remaining: 9.79s
# 1400:	learn: 0.0497594	total: 3.59s	remaining: 9.23s
# 1600:	learn: 0.0446683	total: 4.09s	remaining: 8.7s
# 1800:	learn: 0.0404120	total: 4.61s	remaining: 8.18s
# 2000:	learn: 0.0364061	total: 5.14s	remaining: 7.7s
# 2200:	learn: 0.0327265	total: 5.66s	remaining: 7.2s
# 2400:	learn: 0.0297379	total: 6.18s	remaining: 6.69s
# 2600:	learn: 0.0274452	total: 6.7s	remaining: 6.17s
# 2800:	learn: 0.0251337	total: 7.2s	remaining: 5.65s
# 3000:	learn: 0.0230497	total: 7.73s	remaining: 5.15s
# 3200:	learn: 0.0210692	total: 8.24s	remaining: 4.63s
# 3400:	learn: 0.0192659	total: 8.77s	remaining: 4.12s
# 3600:	learn: 0.0176960	total: 9.28s	remaining: 3.61s
# 3800:	learn: 0.0161864	total: 9.8s	remaining: 3.09s
# 4000:	learn: 0.0149738	total: 10.3s	remaining: 2.58s
# 4200:	learn: 0.0139057	total: 10.8s	remaining: 2.06s
# 4400:	learn: 0.0128424	total: 11.4s	remaining: 1.54s
# 4600:	learn: 0.0118266	total: 11.9s	remaining: 1.03s
# 4800:	learn: 0.0109535	total: 12.4s	remaining: 516ms
# 4999:	learn: 0.0101564	total: 12.9s	remaining: 0us
# fold 3 : RMSE = 0.1237
# 0:	learn: 0.4018050	total: 2.49ms	remaining: 12.5s
# 200:	learn: 0.1227856	total: 526ms	remaining: 12.6s
# 400:	learn: 0.0941791	total: 1.04s	remaining: 11.9s
# 600:	learn: 0.0802911	total: 1.57s	remaining: 11.5s
# 800:	learn: 0.0696276	total: 2.09s	remaining: 10.9s
# 1000:	learn: 0.0617961	total: 2.6s	remaining: 10.4s
# 1200:	learn: 0.0546683	total: 3.19s	remaining: 10.1s
# 1400:	learn: 0.0486467	total: 3.7s	remaining: 9.51s
# 1600:	learn: 0.0433355	total: 4.23s	remaining: 8.98s
# 1800:	learn: 0.0388207	total: 4.75s	remaining: 8.44s
# 2000:	learn: 0.0349177	total: 5.28s	remaining: 7.92s
# 2200:	learn: 0.0315428	total: 5.8s	remaining: 7.38s
# 2400:	learn: 0.0284741	total: 6.33s	remaining: 6.85s
# 2600:	learn: 0.0256651	total: 6.85s	remaining: 6.32s
# 2800:	learn: 0.0229632	total: 7.38s	remaining: 5.79s
# 3000:	learn: 0.0206884	total: 7.92s	remaining: 5.27s
# 3200:	learn: 0.0186746	total: 8.43s	remaining: 4.74s
# 3400:	learn: 0.0169527	total: 8.95s	remaining: 4.21s
# 3600:	learn: 0.0155143	total: 9.44s	remaining: 3.67s
# 3800:	learn: 0.0141298	total: 9.97s	remaining: 3.15s
# 4000:	learn: 0.0129145	total: 10.5s	remaining: 2.62s
# 4200:	learn: 0.0118878	total: 11s	remaining: 2.09s
# 4400:	learn: 0.0108171	total: 11.5s	remaining: 1.57s
# 4600:	learn: 0.0099537	total: 12.1s	remaining: 1.04s
# 4800:	learn: 0.0091235	total: 12.6s	remaining: 522ms
# 4999:	learn: 0.0083554	total: 13.1s	remaining: 0us
# fold 4 : RMSE = 0.1034
# mean RMSE: 0.1236 +- 0.0177

# %%
res_df = pd.DataFrame(results)
res_df = res_df.sort_values('mean_rmse', ascending=False).reset_index(drop=True)
path_metrics = config.CONFIG['paths']['metrics_results']
res_df.to_csv(path_metrics, index=False)
print('Метрики сохранены:', path_metrics)
print(res_df)
# Out:
# Метрики сохранены: C:\newTry2\classicMLpractice\ProjectKaggle\HousePrices\checkpoints\metrics_results.csv
#               model  mean_rmse  std_rmse
# 0               KNN   0.329556  0.026867
# 1      DecisionTree   0.201436  0.009022
# 2  LinearRegression   0.152411  0.046069
# 3             Ridge   0.146807  0.039202
# 4      RandomForest   0.145413  0.018973
# 5        ElasticNet   0.142566  0.042012
# 6             Lasso   0.141237  0.042777
# 7          LightGBM   0.134539  0.018364
# 8           XGBoost   0.125615  0.017377
# 9          CatBoost   0.123610  0.017683
